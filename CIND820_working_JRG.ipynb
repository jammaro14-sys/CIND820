# %%
# %pip install ydata-profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv('https://data.ontario.ca/dataset/1f14addd-e4fc-4a07-9982-ad98db07ef86/resource/4cc07c1b-62ed-4ece-a2a4-d05d0f45081c/download/img-wage-rate-by-edu-age-sex-ft-pt-ca-on-2006-24.csv.csv')

profile = ProfileReport(df, title="EDA Report", explorative=True)
profile.to_file("ydata_report.html")

# %%
profile.to_notebook_iframe()
